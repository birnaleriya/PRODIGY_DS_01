# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\archive\unemployed_population_1978-12_to_2023-07.csv")

# %%
X = list(df.iloc[0:20,0])
Y = list(df.iloc[0:20,3])

# %%
plt.bar(X,Y,color='g',width = 0.4)
plt.title('Unemployment')
plt.xlabel('Date')
plt.ylabel('Age group 25-54')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\archive\unemployed_population_1978-12_to_2023-07.csv")

# %%
plt.hist(df['women'], bins=25, alpha=0.45, color='red')
plt.title('Unemployment')
plt.xticks(rotation=45, ha='right')
plt.show()
